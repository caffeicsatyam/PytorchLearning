# %%
import torch

# %% [markdown]
# # Autograd

# %%
x = torch.tensor(3.0, requires_grad=True)     # if we put requires_grad = true mean we will be want to find derivative of the fucntion

# %%
y = x**2
y               #see it calculated the power
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
print(x.grad)
# Out:
# tensor(6.)

# %%
x = torch.tensor(4.0, requires_grad=True)

# %%
y = x**2

# %%
z = torch.sin(y)

# %%
x, y, z
# Out:
# (tensor(4., requires_grad=True),
#  tensor(16., grad_fn=<PowBackward0>),
#  tensor(-0.2879, grad_fn=<SinBackward0>))

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-7.6613)

# %% [markdown]
# # Creating a simple neural network

# %%
x = torch.tensor(6.7)  #input feature
y = torch.tensor(0.0)  #True label (binary)

w = torch.tensor(1.0)  # weight
b = torch.tensor(0.0)  #Bias

# %%
def binary_cross_entropy(prediction, target):
    epsilon =1e-8
    prediction = torch.clamp(prediction, epsilon, 1-epsilon)
    return -(target*torch.log(prediction) + (1-target)*torch.log(1-prediction))

# %%
# forward Pass
z = w * x + b
y_pred = torch.sigmoid(z)

# Compute binary cross-entropy loss
loss = binary_cross_entropy(y_pred, y)

# %%
# Derivatives
# 1. dL/dy(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred * (1- y_pred))

# %%
dloss_dy_pred
# Out:
# tensor(813.3619)

# %%
dy_pred_dz = y_pred * (1 - y_pred)

dz_dw = z
dz_db = 1

dL_dw = dloss_dy_pred * dy_pred_dz *dz_dw
dl_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Graident of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Graident of loss w.r.t bias (db): {dl_db}")
# Out:
# Manual Graident of loss w.r.t weight (dw): 6.691762447357178
# Manual Graident of loss w.r.t bias (db): 0.998770534992218

# %%
x = torch.tensor(6.7)  #input feature
y = torch.tensor(0.0)  #True label (binary)

w = torch.tensor(1.0, requires_grad=True)  # weight
b = torch.tensor(0.0, requires_grad=True)  #Bias

# %%
z = w*z + b

# %%
y_pred = torch.sigmoid(z)

# %%
loss = binary_cross_entropy(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)
